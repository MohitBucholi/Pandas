# %% [markdown]
# <h1>Pandas

# %%
import pandas as pd

# %%
# Load the data frame
df = pd.read_csv(r"D:\HP\datasets kaggle\tweets.csv")
df
# Out:
#           author                                            content country  \
# 0      katyperry  Is history repeating itself...?#DONTNORMALIZEH...     NaN
# 1      katyperry  @barackobama Thank you for your incredible gra...     NaN
# 2      katyperry                Life goals. https://t.co/XIn1qKMKQl     NaN
# 3      katyperry            Me right now 🙏🏻 https://t.co/gW55C1wrwd     NaN
# 4      katyperry  SISTERS ARE DOIN' IT FOR THEMSELVES! 🙌🏻💪🏻❤️ ht...     NaN
# ...          ...                                                ...     ...
# 52537   ddlovato               Life couldn't be better right now. 😊     NaN
# 52538   ddlovato  First Monday back in action. I'd say 21.6 mile...     NaN
# 52539   ddlovato  Crime shows, buddy, snuggles = the perfect Sun...     NaN
# 52540   ddlovato                          ❄️ http://t.co/sHCFdPpGPa     NaN
# 52541   ddlovato                      ❤️❄️✈️ http://t.co/ixmB5lv17Z     NaN
#
# ...

# %%
# it give the information of data columns and their data type's, null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52542 entries, 0 to 52541
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   author            52542 non-null  object
#  1   content           52542 non-null  object
#  2   country           36 non-null     object
#  3   date_time         52542 non-null  object
#  4   id                52542 non-null  float64
#  5   language          52542 non-null  object
#  6   latitude          1 non-null      float64
#  7   longitude         1 non-null      float64
#  8   number_of_likes   52542 non-null  int64
#  9   number_of_shares  52542 non-null  int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 4.0+ MB

# %%
# it give some statical calculation's
df.describe()
# Out:
#                  id   latitude   longitude  number_of_likes  number_of_shares
# count  5.254200e+04   1.000000    1.000000     52542.000000      52542.000000
# mean   5.741141e+17  37.776973 -122.416523      9637.838339       5386.880857
# std    2.009723e+17        NaN         NaN     18759.083482      11517.259484
# min    6.789717e+09  37.776973 -122.416523         0.000000          0.000000
# 25%    4.485852e+17  37.776973 -122.416523       916.000000        378.000000
# 50%    6.337935e+17  37.776973 -122.416523      2595.500000       1266.000000
# 75%    7.336588e+17  37.776973 -122.416523     10300.750000       5205.000000
# max    8.237200e+17  37.776973 -122.416523    429159.000000     219062.000000

# %% [markdown]
# ##### dataframe_name.iloc['row' , 'column']

# %%
df.iloc[11:20,2:5]
# it return a dataframe
# Out:
#    country         date_time            id
# 11     NaN  25/12/2016 05:45  8.128970e+17
# 12     NaN  24/12/2016 16:26  8.126960e+17
# 13     NaN  23/12/2016 18:42  8.123680e+17
# 14     NaN  23/12/2016 02:22  8.121210e+17
# 15     NaN  21/12/2016 23:05  8.117090e+17
# 16     NaN  21/12/2016 22:42  8.117030e+17
# 17     NaN  16/12/2016 08:24  8.096760e+17
# 18     NaN  07/12/2016 09:03  8.064240e+17
# 19     NaN  07/12/2016 02:35  8.063260e+17

# %% [markdown]
# ##### mean( ), median( ), mode( ), max( ), min( ), sum( )

# %%
# mean of a particular column
df['number_of_likes'].mean()
# Out:
# 9637.838338852727

# %%
# maximun value of a column
df['number_of_likes'].max()
# Out:
# 429159

# %%
# median of a column
df['number_of_shares'].median()
# Out:
# 1266.0

# %%
# minmum of a column
df['number_of_shares'].min()
# Out:
# 0

# %% [markdown]
# ##### Drop column & row
# 1. axis(0) ----> Row
# 2. axis(1) ----> column

# %%
# drop multiple row
df.drop([0,1,2,3],axis=0)
# Out:
#           author                                            content country  \
# 4      katyperry  SISTERS ARE DOIN' IT FOR THEMSELVES! 🙌🏻💪🏻❤️ ht...     NaN
# 5      katyperry  happy 96th gma #fourmoreyears! 🎈 @ LACMA Los A...     NaN
# 6      katyperry  Kyoto, Japan \r\n1. 5. 17. https://t.co/o28M0v...     NaN
# 7      katyperry       🇯🇵 @ Sanrio Puroland https://t.co/eXVev5UMBx     NaN
# 8      katyperry           2017 resolution: to embody authenticity!     NaN
# ...          ...                                                ...     ...
# 52537   ddlovato               Life couldn't be better right now. 😊     NaN
# 52538   ddlovato  First Monday back in action. I'd say 21.6 mile...     NaN
# 52539   ddlovato  Crime shows, buddy, snuggles = the perfect Sun...     NaN
# 52540   ddlovato                          ❄️ http://t.co/sHCFdPpGPa     NaN
# 52541   ddlovato                      ❤️❄️✈️ http://t.co/ixmB5lv17Z     NaN
#
# ...

# %%
df.drop("author",axis=1)
# Out:
#                                                  content country  \
# 0      Is history repeating itself...?#DONTNORMALIZEH...     NaN
# 1      @barackobama Thank you for your incredible gra...     NaN
# 2                    Life goals. https://t.co/XIn1qKMKQl     NaN
# 3                Me right now 🙏🏻 https://t.co/gW55C1wrwd     NaN
# 4      SISTERS ARE DOIN' IT FOR THEMSELVES! 🙌🏻💪🏻❤️ ht...     NaN
# ...                                                  ...     ...
# 52537               Life couldn't be better right now. 😊     NaN
# 52538  First Monday back in action. I'd say 21.6 mile...     NaN
# 52539  Crime shows, buddy, snuggles = the perfect Sun...     NaN
# 52540                          ❄️ http://t.co/sHCFdPpGPa     NaN
# 52541                      ❤️❄️✈️ http://t.co/ixmB5lv17Z     NaN
#
#               date_time            id language  latitude  longitude  \
# 0      12/01/2017 19:52  8.196330e+17       en       NaN        NaN
# ...

# %% [markdown]
# #### Check condition in pandas
# it return boolean value

# %%
df['author'] =='katyperry'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 52537    False
# 52538    False
# 52539    False
# 52540    False
# 52541    False
# Name: author, Length: 52542, dtype: bool

# %% [markdown]
# #### access data using condition

# %%
df.loc[df['author']=='katyperry',:'id']
# Out:
#          author                                            content country  \
# 0     katyperry  Is history repeating itself...?#DONTNORMALIZEH...     NaN
# 1     katyperry  @barackobama Thank you for your incredible gra...     NaN
# 2     katyperry                Life goals. https://t.co/XIn1qKMKQl     NaN
# 3     katyperry            Me right now 🙏🏻 https://t.co/gW55C1wrwd     NaN
# 4     katyperry  SISTERS ARE DOIN' IT FOR THEMSELVES! 🙌🏻💪🏻❤️ ht...     NaN
# ...         ...                                                ...     ...
# 2919  katyperry  We're hungry too. RT @TheDoctorLuke: @katyperr...     NaN
# 2920  katyperry  ERMAHGERD! Cooking class accompanied by my win...     NaN
# 2921  katyperry  #PartOfMe comes out on Blu-Ray/DVD 9/18! Pre-o...     NaN
# 2922  katyperry                                      ANNOUNCEMENT!     NaN
# 2923  katyperry  A little birdie dropped this on me today: Coin...     NaN
#
#              date_time            id
# ...

# %%
df.groupby('author').size()
# Out:
# author
# ArianaGrande     3104
# BarackObama      2863
# Cristiano        2507
# KimKardashian    2939
# TheEllenShow     3147
# Twitter          2290
# YouTube          3077
# britneyspears    2776
# cnnbrk           1842
# ddlovato         2217
# instagram        2577
# jimmyfallon      3123
# jtimberlake      2478
# justinbieber     2000
# katyperry        2924
# ladygaga         2329
# rihanna          2877
# selenagomez      2913
# shakira          2530
# taylorswift13    2029
# dtype: int64

# %%
df['author'].value_counts()
# Out:
# TheEllenShow     3147
# jimmyfallon      3123
# ArianaGrande     3104
# YouTube          3077
# KimKardashian    2939
# katyperry        2924
# selenagomez      2913
# rihanna          2877
# BarackObama      2863
# britneyspears    2776
# instagram        2577
# shakira          2530
# Cristiano        2507
# jtimberlake      2478
# ladygaga         2329
# Twitter          2290
# ddlovato         2217
# taylorswift13    2029
# justinbieber     2000
# cnnbrk           1842
# Name: author, dtype: int64

# %%
df.skew()
# Out:
# id                 -0.989472
# latitude                 NaN
# longitude                NaN
# number_of_likes     5.211018
# number_of_shares    5.023508
# dtype: float64

# %% [markdown]
# #### correlation

# %%
df.corr()
# Out:
#                         id  latitude  longitude  number_of_likes  \
# id                1.000000       NaN        NaN         0.200942
# latitude               NaN       NaN        NaN              NaN
# longitude              NaN       NaN        NaN              NaN
# number_of_likes   0.200942       NaN        NaN         1.000000
# number_of_shares  0.084737       NaN        NaN         0.921523
#
#                   number_of_shares
# id                        0.084737
# latitude                       NaN
# longitude                      NaN
# number_of_likes           0.921523
# number_of_shares          1.000000

# %%
# get_dummies() is used to convert the caterical value into numerical value
pd.get_dummies(data = df,columns=["country"])
# Out:
#           author                                            content  \
# 0      katyperry  Is history repeating itself...?#DONTNORMALIZEH...
# 1      katyperry  @barackobama Thank you for your incredible gra...
# 2      katyperry                Life goals. https://t.co/XIn1qKMKQl
# 3      katyperry            Me right now 🙏🏻 https://t.co/gW55C1wrwd
# 4      katyperry  SISTERS ARE DOIN' IT FOR THEMSELVES! 🙌🏻💪🏻❤️ ht...
# ...          ...                                                ...
# 52537   ddlovato               Life couldn't be better right now. 😊
# 52538   ddlovato  First Monday back in action. I'd say 21.6 mile...
# 52539   ddlovato  Crime shows, buddy, snuggles = the perfect Sun...
# 52540   ddlovato                          ❄️ http://t.co/sHCFdPpGPa
# 52541   ddlovato                      ❤️❄️✈️ http://t.co/ixmB5lv17Z
#
#               date_time            id language  latitude  longitude  \
# 0      12/01/2017 19:52  8.196330e+17       en       NaN        NaN
# ...

# %%
# return the boolean value (value is null: True, value is not null: False)
df.isnull()
# Out:
#        author  content  country  date_time     id  language  latitude  \
# 0       False    False     True      False  False     False      True
# 1       False    False     True      False  False     False      True
# 2       False    False     True      False  False     False      True
# 3       False    False     True      False  False     False      True
# 4       False    False     True      False  False     False      True
# ...       ...      ...      ...        ...    ...       ...       ...
# 52537   False    False     True      False  False     False      True
# 52538   False    False     True      False  False     False      True
# 52539   False    False     True      False  False     False      True
# 52540   False    False     True      False  False     False      True
# 52541   False    False     True      False  False     False      True
#
#        longitude  number_of_likes  number_of_shares
# 0           True            False             False
# ...

# %%
# give the list of categorical value
pd.Categorical(df)
# Out:
# ['author', 'content', 'country', 'date_time', 'id', 'language', 'latitude', 'longitude', 'number_of_likes', 'number_of_shares']
# Categories (10, object): ['author', 'content', 'country', 'date_time', ..., 'latitude', 'longitude', 'number_of_likes', 'number_of_shares']

# %%
df.nunique()
# Out:
# author                 20
# content             52425
# country                 2
# date_time           49590
# id                  43641
# language               32
# latitude                1
# longitude               1
# number_of_likes     19572
# number_of_shares    14599
# dtype: int64

# %%
# return the columns of datadrame
df.columns
# Out:
# Index(['author', 'content', 'country', 'date_time', 'id', 'language',
#        'latitude', 'longitude', 'number_of_likes', 'number_of_shares'],
#       dtype='object')

# %%
# it return the shape of dataframe
df.shape
# Out:
# (52542, 10)

# %%
# it return the size of dataframe
df.size
# Out:
# 525420

# %%
# it return the types of columns of dataframe
df.dtypes
# Out:
# author               object
# content              object
# country              object
# date_time            object
# id                  float64
# language             object
# latitude            float64
# longitude           float64
# number_of_likes       int64
# number_of_shares      int64
# dtype: object

# %%
# access some particular type columns
df.dtypes[df.dtypes == object]
# Out:
# author       object
# content      object
# country      object
# date_time    object
# language     object
# dtype: object

# %% [markdown]
# #### Rename column name's

# %%
df.rename(columns={'country_Vereinigte Staaten':'ctry_vereini','country_Portugal':'ctry_portugal'},inplace=True)
df
# Out:
#           author                                            content country  \
# 0      katyperry  Is history repeating itself...?#DONTNORMALIZEH...     NaN
# 1      katyperry  @barackobama Thank you for your incredible gra...     NaN
# 2      katyperry                Life goals. https://t.co/XIn1qKMKQl     NaN
# 3      katyperry            Me right now 🙏🏻 https://t.co/gW55C1wrwd     NaN
# 4      katyperry  SISTERS ARE DOIN' IT FOR THEMSELVES! 🙌🏻💪🏻❤️ ht...     NaN
# ...          ...                                                ...     ...
# 52537   ddlovato               Life couldn't be better right now. 😊     NaN
# 52538   ddlovato  First Monday back in action. I'd say 21.6 mile...     NaN
# 52539   ddlovato  Crime shows, buddy, snuggles = the perfect Sun...     NaN
# 52540   ddlovato                          ❄️ http://t.co/sHCFdPpGPa     NaN
# 52541   ddlovato                      ❤️❄️✈️ http://t.co/ixmB5lv17Z     NaN
#
# ...

# %% [markdown]
# ## Thank you
